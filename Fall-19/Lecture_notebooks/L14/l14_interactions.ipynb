# %%
library(haven)
wagedata <- read_dta("WAGE1.DTA")

# %%
reg1<- lm(wage~exper, data = wagedata)
summary(reg1)
# Out:
# Call:
# lm(formula = wage ~ exper, data = wagedata)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -4.936 -2.458 -1.112  1.077 18.716
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  5.37331    0.25699  20.908  < 2e-16 ***
# exper        0.03072    0.01181   2.601  0.00955 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 3.673 on 524 degrees of freedom
# Multiple R-squared:  0.01275,	Adjusted R-squared:  0.01086
# F-statistic: 6.766 on 1 and 524 DF,  p-value: 0.009555

# %%
reg2<- lm(wage~log(exper), data = wagedata)
summary(reg2)
# Out:
# Call:
# lm(formula = wage ~ log(exper), data = wagedata)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -5.167 -2.310 -1.072  1.220 18.362
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   4.1202     0.3876  10.630  < 2e-16 ***
# log(exper)    0.7417     0.1479   5.014 7.29e-07 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 3.611 on 524 degrees of freedom
# Multiple R-squared:  0.04579,	Adjusted R-squared:  0.04397
# F-statistic: 25.14 on 1 and 524 DF,  p-value: 7.291e-07

# %%
reg3<-lm(wage~exper + expersq, data = wagedata)
summary(reg3)
# Out:
# Call:
# lm(formula = wage ~ exper + expersq, data = wagedata)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -5.5916 -2.1440 -0.8603  1.1801 17.7649
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  3.7254058  0.3459392  10.769  < 2e-16 ***
# exper        0.2981001  0.0409655   7.277 1.26e-12 ***
# expersq     -0.0061299  0.0009025  -6.792 3.02e-11 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 3.524 on 523 degrees of freedom
# Multiple R-squared:  0.09277,	Adjusted R-squared:  0.0893
# F-statistic: 26.74 on 2 and 523 DF,  p-value: 8.774e-12

# %%
plot(wage~exper, data = wagedata)
# Out:
# plot without title

# %%
hpdata<-read_dta("hprice1.dta")
# Out:
#   price   assess bdrms lotsize sqrft colonial lprice   lassess  llotsize
# 1 300.000 349.1  4     6126    2438  1        5.703783 5.855359 8.720297
# 2 370.000 351.5  3     9903    2076  1        5.913503 5.862210 9.200593
# 3 191.000 217.7  3     5200    1374  0        5.252274 5.383118 8.556414
# 4 195.000 231.8  3     4600    1448  1        5.273000 5.445875 8.433811
# 5 373.000 319.1  4     6095    2514  1        5.921578 5.765504 8.715224
# 6 466.275 414.5  5     8566    2754  1        6.144775 6.027073 9.055556
#   lsqrft
# 1 7.798934
# 2 7.638198
# 3 7.225482
# 4 7.277938
# 5 7.829630
# 6 7.920810

# %%
reg4<-lm(price ~ sqrft + bdrms + sqrft*bdrms, data = hpdata)
summary(reg4)
# Out:
# Call:
# lm(formula = price ~ sqrft + bdrms + sqrft * bdrms, data = hpdata)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -146.858  -33.911   -8.586   27.900  212.400
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 181.69082   92.18885   1.971   0.0520 .
# sqrft         0.03262    0.04364   0.747   0.4569
# bdrms       -35.95534   24.01237  -1.497   0.1380
# sqrft:bdrms   0.02345    0.01016   2.308   0.0234 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 61.5 on 84 degrees of freedom
# Multiple R-squared:  0.6539,	Adjusted R-squared:  0.6415
# F-statistic:  52.9 on 3 and 84 DF,  p-value: < 2.2e-16

# %%
reg5<- lm(price~sqrft + bdrms, data = hpdata)
summary(reg5)
# Out:
# Call:
# lm(formula = price ~ sqrft + bdrms, data = hpdata)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -127.627  -42.876   -7.051   32.589  229.003
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -19.31500   31.04662  -0.622    0.536
# sqrft         0.12844    0.01382   9.291 1.39e-14 ***
# bdrms        15.19819    9.48352   1.603    0.113
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 63.04 on 85 degrees of freedom
# Multiple R-squared:  0.6319,	Adjusted R-squared:  0.6233
# F-statistic: 72.96 on 2 and 85 DF,  p-value: < 2.2e-16

# %%
reg6<-lm(price~sqrft + bdrms + assess, data= hpdata)
summary(reg6)
# Out:
# Call:
# lm(formula = price ~ sqrft + bdrms + assess, data = hpdata)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -105.355  -19.571   -1.451   20.492  195.815
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -39.063945  21.548835  -1.813   0.0734 .
# sqrft        -0.004806   0.016735  -0.287   0.7747
# bdrms        11.835580   6.562024   1.804   0.0749 .
# assess        0.950340   0.098004   9.697 2.35e-15 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 43.56 on 84 degrees of freedom
# Multiple R-squared:  0.8263,	Adjusted R-squared:  0.8201
# F-statistic: 133.2 on 3 and 84 DF,  p-value: < 2.2e-16

# %%
gpadata<-read_dta("gpa2.dta")
head(gpadata)
reg7<-lm(colgpa~sat+ hsperc + hsize + hsizesq, data= gpadata)
summary(reg7)
# Out:
#   sat  tothrs colgpa athlete verbmath hsize hsrank hsperc   female white black
# 1  920  43    2.04   1       0.48387  0.10    4    40.00000 1      0     0
# 2 1170  18    4.00   0       0.82813  9.40  191    20.31915 0      1     0
# 3  810  14    1.78   1       0.88372  1.19   42    35.29412 0      1     0
# 4  940  40    2.42   0       0.80769  5.71  252    44.13310 0      1     0
# 5 1180  18    2.61   0       0.73529  2.14   86    40.18692 0      1     0
# 6  980 114    3.03   0       0.81481  2.68   41    15.29851 1      1     0
#   hsizesq
# 1  0.0100
# 2 88.3600
# 3  1.4161
# 4 32.6041
# 5  4.5796
# 6  7.1824
# Call:
# lm(formula = colgpa ~ sat + hsperc + hsize + hsizesq, data = gpadata)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -2.57543 -0.35081  0.03342  0.39945  1.81683
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  1.493e+00  7.534e-02  19.812  < 2e-16 ***
# sat          1.492e-03  6.521e-05  22.886  < 2e-16 ***
# hsperc      -1.386e-02  5.610e-04 -24.698  < 2e-16 ***
# hsize       -6.088e-02  1.650e-02  -3.690 0.000228 ***
# hsizesq      5.460e-03  2.270e-03   2.406 0.016191 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.5599 on 4132 degrees of freedom
# Multiple R-squared:  0.2781,	Adjusted R-squared:  0.2774
# F-statistic:   398 on 4 and 4132 DF,  p-value: < 2.2e-16

# %%
#predict values
predgpa1 = 1.493 + 1200*.001492 -.01386*30 -.06088*5+.00546*25
#print
print("predgpa1")
predgpa1
#or, extract.  Summary stores beta coefficients in the term "coef"
summary(reg7)$coef
predgpa2 = sum(c(1,1200,30,5,25)*summary(reg7)$coef[,1])
#print
print("predgpa2")
predgpa2
# Out:
# [1] "predgpa1"
# [1] 2.6997
#             Estimate     Std. Error   t value    Pr(>|t|)
# (Intercept)  1.492652209 7.534142e-02  19.811840  1.585529e-83
# sat          0.001492497 6.521336e-05  22.886370 3.027519e-109
# hsperc      -0.013855782 5.610052e-04 -24.698136 9.760768e-126
# hsize       -0.060881453 1.650123e-02  -3.689509  2.275801e-04
# hsizesq      0.005460295 2.269848e-03   2.405577  1.619060e-02
# [1] "predgpa2"
# [1] 2.700075

# %%
#transform data to get CI
gpadata$sat0<- gpadata$sat-1200
gpadata$hsperc0 <-gpadata$hsperc-30
gpadata$hsize0<-gpadata$hsize-5
gpadata$hsizesq0<-gpadata$hsizesq-25

reg8<-lm(colgpa~sat0+hsperc0 + hsize0 + hsizesq0, data = gpadata)
summary(reg8)
# Out:
# Call:
# lm(formula = colgpa ~ sat0 + hsperc0 + hsize0 + hsizesq0, data = gpadata)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -2.57543 -0.35081  0.03342  0.39945  1.81683
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  2.700e+00  1.988e-02 135.833  < 2e-16 ***
# sat0         1.492e-03  6.521e-05  22.886  < 2e-16 ***
# hsperc0     -1.386e-02  5.610e-04 -24.698  < 2e-16 ***
# hsize0      -6.088e-02  1.650e-02  -3.690 0.000228 ***
# hsizesq0     5.460e-03  2.270e-03   2.406 0.016191 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.5599 on 4132 degrees of freedom
# Multiple R-squared:  0.2781,	Adjusted R-squared:  0.2774
# F-statistic:   398 on 4 and 4132 DF,  p-value: < 2.2e-16
