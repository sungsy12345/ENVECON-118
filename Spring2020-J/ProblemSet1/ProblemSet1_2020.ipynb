# %% [markdown]
# # Problem Set 1, Spring 2020, Villas-Boas

# %% [markdown]
# Due <u>Tuesday, February 11 at 9:30am</u>
#
# Submit materials (all handwritten/typed answers, Excel workbooks, and R reports) as one combined pdf on [Gradescope](https://www.gradescope.com/courses/85265).

# %% [markdown]
# # Exercise 1 (Excel). Relationship between Gasoline Consumption Data and Price of Gasoline in 18 OECD countries.

# %% [markdown]
# We will use data from Baltagi (2005) on gasoline consumption  for 18 OECD countries. The original data span 19 years. In this first problem set we will only use the year 1969.
#
# This exercise is to be completed using EXCEL.
# Looking at the first graph, there appears to be an association between Gasoline consumption per car and the price of gasoline.
#  We will establish a simple linear relationship on a subset of 9 countries at a time.

# %% [markdown]
# <center><b> Table 1: Log of Gasoline Consumption Per Car and Log of Price of Gasoline, Sample 1</b></center>
#
# |CountryName	|	log of Gasoline Consumption per Car	|	log of Gasoline Price	|
# |-----------|---------------|---------------|
# |sample 1	|	log of Y	|	log of X	|
# |AUSTRIA	|	4.046355	|	-0.5591105	|
# |BELGIUM	|	3.854601	|	-0.3548085	|
# |CANADA	|	4.864433	|	-1.0368639	|
# |DENMARK	|	4.173561	|	-0.4068792	|
# |FRANCE	|	3.77346	|	-0.3151909	|
# |GERMANY	|	3.899185	|	-0.5892314	|
# |GREECE	|	4.894773	|	-0.17987	|
# |IRELAND	|	4.208613	|	-0.2716284	|
# |ITALY	|	3.737389	|	-0.2475668	|

# %% [markdown]
# (a) Use Excel to create a scatter plot of these observations. Don't forget to (1) label the axes and their units, and (2) title your graph.  **You should use the tables provided here for these calculations, not the actual observations from the .csv data file in the problem set folder or from datahub (enter the data into excell manually yourself).**

# %% [markdown]
# (b) This question has two parts.  First: Estimate the linear relationship between the log of Gasoline consumption per car (log(Y)) and the log of gasoline prices  (log(X)) by OLS, showing all intermediate calculations as we saw in the lecture 3 slides (use Excel to create the table and show all the steps).

# %% [markdown]
# (c) Second: interpret the value of the estimated parameters $\hat{\beta}_0$ and $\hat{\beta}_1$.
# 	$\widehat{logY}_i = \hat{\beta}_0 + \hat{\beta}_1 logx_i + \epsilon_i$ for  $i =$ first 9 countries.

# %% [markdown]
# write your answer here:

# %% [markdown]
# (c) In your Excel file table, compute the fitted value and the residual for each observation, and verify that the residuals (approximately) sum to 0.

# %% [markdown]
# (d) According to the estimated relation, what is the predicted gas consumption per car, in Level not log, that is, $\widehat{Y}$ for the
#  a country with a log gas price of $-1.5$? (Pay attention to units)

# %% [markdown]
# write your answer here:

# %% [markdown]
# (e) How much of the variation in per capita log gasoline consumption in these 9 countries is explained by log of price of gasoline in the countries?

# %% [markdown]
# write your answer here:

# %% [markdown]
# (f) Second Sample:  Repeat exercises (a) to (e) for the  additional set of 9 countries in the table below. **You should use the table numbers provided below for these calculations, not the actual observations from the .csv data file in the problem set folder. So, enter the data into Excel manually yourself.**

# %% [markdown]
# <center><b> Table 2: Log of Gasoline Consumption Per Car and Log of Price of Gasoline, Sample 2</b></center>
#
# |CountryName	|	log of Gasoline Consumption per Car	|	log of Gasoline Price	|
# |-----------|---------------|---------------|
# |sample 2	|	log of Y	|	log of X	|
# |JAPAN	|	4.51829	|	-0.4168502	|
# |NETHERLANDS	|	3.987689	|	-0.4169496	|
# |NORWAY	|	4.086823	|	-0.3382305	|
# |SPAIN	|	3.994103	|	0.6694895	|
# |SWEDEN	|	3.991715	|	-2.7319041	|
# |SWITZERLAND	|	4.21129	|	-0.9181216	|
# |TURKEY	|	5.720705	|	-0.2984542	|
# |U.K.	|	3.948058	|	-0.3833246	|
# |U.S.A.	|	4.841383	|	-1.2231427	|

# %% [markdown]
# (g) How do your estimates of $\hat{\beta}_0$ and $\hat{\beta}_1$ change between Sample 1 and Sample 2? Briefly explain this variation in a few sentences.

# %% [markdown]
# write your answer here:

# %% [markdown]
# Save a copy of your workbook as a pdf (OLS tables and scatter plot) to combine with the later work.

# %% [markdown]
# # Exercise 2. Functional Forms

# %% [markdown]
# (a) An economist asks you whether they should estimate a **linear** relationship between per car log of gasoline consumption and log of price using the sample of all 18 OECD countries.  You will make your decision based on the figure below. If you answer {yes} or {no} , please say why.
#
# ![fig1.jpg](attachment:fig1.jpg)

# %% [markdown]
# write your answer here:

# %% [markdown]
# (b) What is the fit going to be like if you impose a straight line on this figure as the relationship between log Y and Log X? Will you get a High or a low fit (when comparing data and predictions)? Answer briefly in writing, no need to estimate the regression, the residuals and the fitl; you should be able to argue based on the figure and by you imposing a straight line on the data visually.

# %% [markdown]
# write your answer here:

# %% [markdown]
# Suppose you estimate alternative specifications now:
#
# A linear relationship: $\hat{Y}_i = 90.6 - 10.8 \: X_i + \epsilon_i$
#
# A linear-log relationship: $\hat{Y}_i =   4.3 - 0.17\: log(X)_i+ \epsilon_i$
#
# A log-log relationship: $log(\hat{Y})_i  = 4.25 - 0.0334 \: log(X)_i+ \epsilon_i$
#
# Note that it is convention to always use the natural log.

# %% [markdown]
# (c)  Interpret the parameter on gasoline price X  (or log of gasoline price  log(X)) in each of these equations.

# %% [markdown]
# write your answer here:

# %% [markdown]
# (d) What is the predicted per car gasoline consumption in dollars for a country with a gasoline price of 2?

# %% [markdown]
# write your answer here:

# %% [markdown]
# # Exercise 3. Importing data into R and Basic R first commands

# %% [markdown]
# For the purposes of this class, we will be using a cloud-based version of RStudio provided through UC Berkeley's _Datahub_.
# If you already have an installation of R/RStudio on your personal computer and prefer to work offline, you can download the data for this assignment from bCourses (Make sure to install/update all packages mentioned in the problem sets in order to prevent issues regarding deprecated or outdated packages). The data files can be accessed directly  through $Datahub$ and do not require you to install anything on your computer. This exercise is designed to get you familiar with accessing the service, loading data, and obtaining summary statistics. To start off, we're going to use Jupyter notebooks to help familiarize you with some R commands.

# %% [markdown]
#  (a) Load the datafile *dataPset1\_1969.csv* into $R$ (since this is a *.csv* file, you should use the `read.csv()` command).

# %%
Delete this text and replace with R command to do task

# %% [markdown]
# (b) Provide basic summary statistics on the log of Gas Consumption per car (_LGASPCAR_) in the
# dataframe.
# Use the `summary()` command. This command is part of base $R$, so you do not need to load any packages before using it.

# %%
Delete this text and replace with R command to do task

# %% [markdown]
# What is the median value of log gasoline consumption per car?

# %% [markdown]
# Write your answer here:

# %% [markdown]
# (c) Next, generate custom summary statistics on the Log of Gasoline Price Variable (_LRPMG_) using
# the `summarize()` command provided by `dplyr`. You will need to call the `tidyverse`
# package with the `library()` command to use it. `tidyverse` is a collection of packages
# designed for data science. It includes `dplyr` and several other packages we will use this term.

# %%
Delete this text and replace with R command to do task

# %% [markdown]
# What are a) the number of observations, and b) the value of the 95th percentile of log gasoline price in the sample?
# (For help generating the statistics, type `?summarize` in the console and hit enter, then select the `dplyr` function)

# %% [markdown]
# Write your answer here:

# %% [markdown]
# Create a scatter plot of the LGASPCAR and LRPMG data.  Use
#
# `fig <- plot(x, y, main = "Scatter of tba", xlab = "Log(X) etc", ylab = "Log Y etc")`
#
# filling in x and y appropriately and naming the title/labels to effectively communicate the contents of the plot.

# %%
Delete this text and replace with R command to do task

# %% [markdown]
# Compile the report of your $R$ script and save a pdf to your computer (note: this can be done by
# going to **File > Download As > PDF Via Chrome** in the menu. You will use **PDF Via Chrome** regardless of the web browser you are on).
